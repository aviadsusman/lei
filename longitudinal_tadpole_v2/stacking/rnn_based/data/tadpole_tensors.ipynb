# %%
# %cd ../../../..
# %pwd
# Out:
# /sc/arion/projects/pandeg01a/susmaa01/lei
# /sc/arion/projects/pandeg01a/susmaa01/lei/.venv/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# '/sc/arion/projects/pandeg01a/susmaa01/lei'

# %%
import pickle as pkl
import pandas as pad_sequence
import torch

# %%
with open("/sc/arion/projects/pandeg01a/susmaa01/lei/longitudinal_tadpole_v2/data/40_5/core_24.pkl", "rb") as file:
    core = pkl.load(file)
with open("/sc/arion/projects/pandeg01a/susmaa01/lei/longitudinal_tadpole_v2/data/40_5/total_cohort.pkl", "rb") as file:
    total = pkl.load(file)

# %%
def get_core(row):
    if row['vis_info', 'RID'] in core.index:
        if row['vis_info', 'VISCODE'] in core[row['vis_info', 'RID']]:
            return True
        else:
            return False    
    else:
        return False

core_cohort = total[total.apply(get_core, axis=1)].reset_index(drop=True)

# %%
for sample in core_cohort['vis_info','RID'].unique():
    sample_rows = core_cohort[]
# Out:
# 4
# 5
# 6
# 8
# 14
# 15
# 16
# 19
# 21
# 22
# 23
# 31
# 33
# 35
# 38
# 40
# 41
# 42
# 43
# 44
# 45
# 47
# 50
# 51
# 54
# 55
# 56
# 57
# 58
# 59
# 60
# 61
# 66
# 67
# 68
# 69
# 70
# 72
# 74
# 972
# 77
# 80
# 81
# 86
# 87
# 89
# 90
# 95
# 96
# 97
# 98
# 101
# 919
# 102
# 103
# 106
# 107
# 108
# 111
# 112
# 113
# 116
# 118
# 120
# 123
# 125
# 126
# 127
# 128
# 130
# 135
# 138
# 141
# 142
# 150
# 155
# 156
# 158
# 159
# 160
# 161
# 166
# 168
# 169
# 171
# 172
# 173
# 176
# 177
# 179
# 184
# 186
# 187
# 188
# 195
# 196
# 200
# 204
# 205
# 210
# 214
# 217
# 222
# 223
# 225
# 227
# 229
# 230
# 231
# 232
# 240
# 241
# 243
# 245
# 249
# 256
# 912
# 257
# 258
# 259
# 260
# 262
# 269
# 272
# 273
# 276
# 282
# 283
# 284
# 285
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 298
# 301
# 303
# 307
# 311
# 312
# 314
# 315
# 319
# 324
# 325
# 326
# 327
# 331
# 336
# 337
# 344
# 351
# 352
# 354
# 359
# 361
# 362
# 369
# 376
# 377
# 378
# 382
# 384
# 386
# 388
# 389
# 390
# 393
# 394
# 397
# 401
# ...
